# %% [markdown]
# # Model Comparison

# %% [markdown]
# | Model | Best Params | Accuracy | Precision | Recall | F1 |
# |------|------|------|------|------|------|
# | Logistic Regression | – | 0.5829 | 0.5962 | 0.7766 | 0.6746 |
# | Logistic Regression + GridSearchCV | C=0.01 | 0.5827 | 0.5959 | 0.7773 | 0.6746 |
# | SGDClassifier + GridSearchCV | C=0.01 | 0.5827 | 0.5959 | 0.7773 | 0.6746 |
# | LinearSVC + GridSearchCV | C=0.01 | 0.5827 | 0.5959 | 0.7773 | 0.6746 |
# | Random Forest | – | 0.6409 | 0.6715 | 0.6944 | 0.6828 |

# %% [markdown]
# ## Random Forest achieved the best overall performance with the highest Accuracy and F1 Score among the tested models.
