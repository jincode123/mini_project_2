# %% [markdown]
# # Feature relationships

# %%
import importlib
import src.data
importlib.reload(src.data)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.preprocessing_data import prepare_training_data
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
from src.data import load_raw_tables, prepare_delivery_events, build_master_df, add_engineering_features

# %%
base_path = r"C:\Users\jinfe\.cache\kagglehub\datasets\yogape\logistics-operations-database\versions\1"
tables = load_raw_tables(base_path)
delivery_events = prepare_delivery_events(tables["delivery_events"])
df = build_master_df(
    delivery_events,
    tables["trips"],
    tables["loads"],
    tables["drivers"],
    tables["trucks"],
    tables["routes"],
    tables["customers"]
)
df = add_engineering_features(df)

# %%
df
# Out:
#            event_id       load_id       trip_id event_type facility_id  \
# 0       EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1       EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2       EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3       EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4       EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
# ...             ...           ...           ...        ...         ...
# 170815  EVT00170816  LOAD00085408  TRIP00085408   Delivery    FAC00045
# 170816  EVT00170817  LOAD00085409  TRIP00085409     Pickup    FAC00025
# 170817  EVT00170818  LOAD00085409  TRIP00085409   Delivery    FAC00001
# 170818  EVT00170819  LOAD00085410  TRIP00085410     Pickup    FAC00027
# 170819  EVT00170820  LOAD00085410  TRIP00085410   Delivery    FAC00019
#
#                 scheduled_datetime            actual_datetime  \
# 0       2022-01-01 18:00:00.000000 2022-01-01 20:58:55.918185
# 1       2022-01-02 23:10:55.918185 2022-01-02 21:30:22.142060
# 2       2022-01-01 18:00:00.000000 2022-01-01 17:37:26.608430
# 3       2022-01-02 02:13:26.608430 2022-01-02 05:55:46.238257
# 4       2022-01-01 08:00:00.000000 2022-01-01 07:28:02.169634
# ...                            ...                        ...
# 170815  2025-01-01 17:57:42.158981 2025-01-01 15:19:00.254154
# 170816  2024-12-31 13:00:00.000000 2024-12-31 16:37:42.056974
# 170817  2025-01-02 16:31:42.056974 2025-01-02 21:15:48.779380
# 170818  2024-12-31 06:00:00.000000 2024-12-31 05:30:59.579843
# 170819  2025-01-01 07:30:59.579843 2025-01-01 13:06:58.729240
#
#         detention_minutes  on_time_flag location_city  ...  \
# 0                       0         False       Houston  ...
# 1                     230          True       Detroit  ...
# 2                      62          True   Kansas City  ...
# 3                      67         False  Indianapolis  ...
# 4                      83          True      Columbus  ...
# ...                   ...           ...           ...  ...
# 170815                126         False      Portland  ...
# 170816                 13         False  Philadelphia  ...
# 170817                 81         False       Seattle  ...
# 170818                 48          True        Dallas  ...
# 170819                 59         False      New York  ...
#
#        typical_transit_days  customer_type month  truck_age_at_event  \
# 0                         2           Spot     1                 7.0
# 1                         2           Spot     1                 7.0
# 2                         1           Spot     1                 7.0
# 3                         1           Spot     1                 7.0
# 4                         4           Spot     1                 4.0
# ...                     ...            ...   ...                 ...
# 170815                    2       Contract     1                 9.0
# 170816                    4      Dedicated    12                 8.0
# 170817                    4      Dedicated     1                 9.0
# 170818                    2      Dedicated    12                 9.0
# 170819                    2      Dedicated     1                10.0
#
#         distance_deviation is_home_terminal detention_risk_index  \
# 0                       43                0               1051.0
# 1                       43                0               1897.0
# 2                       -4                0               1457.0
# 3                       -4                0               2246.0
# 4                      177                0               2166.0
# ...                    ...              ...                  ...
# 170815                   4                0               2526.0
# 170816                  29                0               2123.0
# 170817                  29                0               1160.0
# 170818                  40                0               1319.0
# 170819                  40                0               2811.0
#
#        efficiency_ratio revenue_density  is_winter
# 0              0.893750        0.158779          1
# 1              0.893750        0.158779          1
# 2              0.687500        0.044106          1
# 3              0.687500        0.044106          1
# 4              1.480000        0.201464          1
# ...                 ...             ...        ...
# 170815         0.707000        0.314411          1
# 170816         0.737778        0.184528          1
# 170817         0.664000        0.184528          1
# 170818         0.682000        0.388001          1
# 170819         0.620000        0.388001          1
#
# [170820 rows x 51 columns]

# %%
# Calculating the percentage of missing values for each column
missing_data = df.isnull().sum()
missing_percentage = (missing_data[missing_data > 0] / df.shape[0]) * 100

# Prepare values
missing_percentage.sort_values(ascending=True, inplace=True)

# Plot the barh chart
fig, ax = plt.subplots(figsize=(15, 4))
ax.barh(missing_percentage.index, missing_percentage, color='#ff6200')

# Annotate the values and indexes
for i, (value, name) in enumerate(zip(missing_percentage, missing_percentage.index)):
    ax.text(value+0.5, i, f"{value:.2f}%", ha='left', va='center', fontweight='bold', fontsize=18, color='black')

# Set x-axis limit
ax.set_xlim([0, 40])

# Add title and xlabel
plt.title("Percentage of Missing Values", fontweight='bold', fontsize=22)
plt.xlabel('Percentages (%)', fontsize=16)
plt.show()

# %%
# Extracting rows with missing values in 'CustomerID' or 'Description' columns
df[df['is_home_terminal'].isnull() | df['years_experience'].isnull()| df['efficiency_ratio'].isnull()| df['truck_age_at_event'].isnull()]
# Out:
#            event_id       load_id       trip_id event_type facility_id  \
# 132     EVT00000133  LOAD00000067  TRIP00000067     Pickup    FAC00009
# 133     EVT00000134  LOAD00000067  TRIP00000067   Delivery    FAC00030
# 138     EVT00000139  LOAD00000070  TRIP00000070     Pickup    FAC00028
# 139     EVT00000140  LOAD00000070  TRIP00000070   Delivery    FAC00003
# 146     EVT00000147  LOAD00000074  TRIP00000074     Pickup    FAC00005
# ...             ...           ...           ...        ...         ...
# 170479  EVT00170480  LOAD00085240  TRIP00085240   Delivery    FAC00003
# 170496  EVT00170497  LOAD00085249  TRIP00085249     Pickup    FAC00045
# 170497  EVT00170498  LOAD00085249  TRIP00085249   Delivery    FAC00027
# 170730  EVT00170731  LOAD00085366  TRIP00085366     Pickup    FAC00021
# 170731  EVT00170732  LOAD00085366  TRIP00085366   Delivery    FAC00045
#
#                 scheduled_datetime            actual_datetime  \
# 132     2022-01-01 11:00:00.000000 2022-01-01 14:10:03.426897
# 133     2022-01-03 06:10:03.426897 2022-01-03 05:15:42.502952
# 138     2022-01-01 08:00:00.000000 2022-01-01 10:14:01.149459
# 139     2022-01-02 00:26:01.149459 2022-01-02 03:32:28.357242
# 146     2022-01-02 07:00:00.000000 2022-01-02 08:49:00.625747
# ...                            ...                        ...
# 170479  2024-12-30 08:12:11.270442 2024-12-30 12:24:14.755622
# 170496  2024-12-30 11:00:00.000000 2024-12-30 14:47:45.266716
# 170497  2024-12-31 19:11:45.266716 2024-12-31 17:20:31.512351
# 170730  2024-12-31 08:00:00.000000 2024-12-31 10:07:47.158529
# 170731  2024-12-31 11:49:47.158529 2024-12-31 13:03:23.301596
#
#         detention_minutes  on_time_flag location_city  ...  \
# 132                    96         False      Columbus  ...
# 133                   158          True   Los Angeles  ...
# 138                    52         False       Phoenix  ...
# 139                   211         False        Denver  ...
# 146                     0          True  Philadelphia  ...
# ...                   ...           ...           ...  ...
# 170479                 67         False     Charlotte  ...
# 170496                 57         False   Minneapolis  ...
# 170497                 51          True   Los Angeles  ...
# 170730                128         False  Philadelphia  ...
# 170731                  0          True      New York  ...
#
#        typical_transit_days  customer_type month  truck_age_at_event  \
# 132                       3      Dedicated     1                 6.0
# 133                       3      Dedicated     1                 6.0
# 138                       1       Contract     1                 NaN
# 139                       1       Contract     1                 NaN
# 146                       4      Dedicated     1                 NaN
# ...                     ...            ...   ...                 ...
# 170479                    1           Spot    12                 9.0
# 170496                    3       Contract    12                 9.0
# 170497                    3       Contract    12                 9.0
# 170730                    1       Contract    12                 9.0
# 170731                    1       Contract    12                 9.0
#
#         distance_deviation is_home_terminal detention_risk_index  \
# 132                    164                0               4062.0
# 133                    164                0               2050.0
# 138                     38                0               2488.0
# 139                     38                0               1287.0
# 146                    208                0               2616.0
# ...                    ...              ...                  ...
# 170479                  38                0               4098.0
# 170496                   0                0               2541.0
# 170497                   0                0               3238.0
# 170730                   1                0               2288.0
# 170731                   1                0               2841.0
#
#        efficiency_ratio revenue_density  is_winter
# 132            0.812857        0.155007          1
# 133            0.812857        0.155007          1
# 138                 NaN        0.032773          1
# 139                 NaN        0.032773          1
# 146                 NaN        0.246600          1
# ...                 ...             ...        ...
# 170479         0.728000        0.188906          1
# 170496         0.663000        0.138465          1
# 170497         0.663000        0.138465          1
# 170730         0.594000        0.006914          1
# 170731         0.594000        0.006914          1
#
# [6698 rows x 51 columns]

# %%
# Removing rows with missing values in 'CustomerID' and 'Description' columns
df = df.dropna(subset=['is_home_terminal', 'years_experience','efficiency_ratio','truck_age_at_event'])
df.head()
# Out:
#       event_id       load_id       trip_id event_type facility_id  \
# 0  EVT00000001  LOAD00000001  TRIP00000001     Pickup    FAC00034
# 1  EVT00000002  LOAD00000001  TRIP00000001   Delivery    FAC00046
# 2  EVT00000003  LOAD00000002  TRIP00000002     Pickup    FAC00015
# 3  EVT00000004  LOAD00000002  TRIP00000002   Delivery    FAC00050
# 4  EVT00000005  LOAD00000003  TRIP00000003     Pickup    FAC00001
#
#            scheduled_datetime            actual_datetime  detention_minutes  \
# 0  2022-01-01 18:00:00.000000 2022-01-01 20:58:55.918185                  0
# 1  2022-01-02 23:10:55.918185 2022-01-02 21:30:22.142060                230
# 2  2022-01-01 18:00:00.000000 2022-01-01 17:37:26.608430                 62
# 3  2022-01-02 02:13:26.608430 2022-01-02 05:55:46.238257                 67
# 4  2022-01-01 08:00:00.000000 2022-01-01 07:28:02.169634                 83
#
#    on_time_flag location_city  ... typical_transit_days  customer_type month  \
# 0         False       Houston  ...                    2           Spot     1
# 1          True       Detroit  ...                    2           Spot     1
# 2          True   Kansas City  ...                    1           Spot     1
# 3         False  Indianapolis  ...                    1           Spot     1
# 4          True      Columbus  ...                    4           Spot     1
#
#    truck_age_at_event  distance_deviation is_home_terminal  \
# 0                 7.0                  43                0
# 1                 7.0                  43                0
# 2                 7.0                  -4                0
# 3                 7.0                  -4                0
# 4                 4.0                 177                0
#
#   detention_risk_index efficiency_ratio revenue_density  is_winter
# 0               1051.0          0.89375        0.158779          1
# 1               1897.0          0.89375        0.158779          1
# 2               1457.0          0.68750        0.044106          1
# 3               2246.0          0.68750        0.044106          1
# 4               2166.0          1.48000        0.201464          1
#
# [5 rows x 51 columns]

# %%
# Final Column Selection (The Optimized List)
final_columns = [
    'on_time_flag', 
    'location_state'
    'facility_congestion_score', 
    'facility_detention_avg',
    'hour_of_day', 
    'day_of_week', 
    'event_type',
    'booking_type',
    'weight_lbs', 
    'pieces',
    'revenue',
    'load_type',
    'years_experience', 
    'truck_age_at_event',
    'average_mpg', 
    'idle_time_hours',
    'distance_deviation',
    'is_home_terminal', 
    'detention_risk_index', 
    'efficiency_ratio', 
    'revenue_density',
    'is_winter'
]

# %%
# Separate Features and Target
categorical_cols = ['day_of_week', 'event_type', 'booking_type', 'load_type','location_state']
numeric_cols = [
    'facility_congestion_score', 'facility_detention_avg', 'hour_of_day', 
    'weight_lbs', 'pieces', 'revenue', 'years_experience', 
    'truck_age_at_event', 'average_mpg', 'idle_time_hours', 'distance_deviation',
    'is_home_terminal', 'detention_risk_index', 'efficiency_ratio', 'revenue_density','is_winter'
]
target = 'on_time_flag'

# %%
# Create df for model training
df_model = df[categorical_cols + numeric_cols + [target]].copy()

# %%
# HEATMAP: Correlation of Numeric Features
plt.figure(figsize=(12, 8))
correlation_matrix_n = df_model[numeric_cols + [target]].corr()
corr_filtered = correlation_matrix_n.copy()
corr_filtered[(corr_filtered > -0.1) & (corr_filtered < 0.1)] = np.nan
# create upper-triangle mask
mask = np.triu(np.ones_like(correlation_matrix_n, dtype=bool))
sns.heatmap(corr_filtered, annot=True, cmap='coolwarm', fmt=".2f", mask=mask,)
plt.title('Correlation Heatmap: Logistics Performance Drivers')
plt.show() # Or plt.savefig('heatmap.png')

# %%
# ONE-HOT ENCODING to convertstext categories into 0/1 columns
df_encoded = pd.get_dummies(df_model, columns=categorical_cols, drop_first=True)

dummy_cols = [col for col in df_encoded.columns if any(col.startswith(cat + "_") for cat in categorical_cols)]

correlation_matrix_c = df_encoded[dummy_cols + [target]].corr()

# %%
# HEATMAP: Correlation of Numeric Features
plt.figure(figsize=(16,12))
correlation_matrix_c = df_encoded[dummy_cols + [target]].corr()
corr_filtered = correlation_matrix_c.copy()
# hide weak correlations
corr_filtered[(corr_filtered > -0.1) & (corr_filtered < 0.1)] = np.nan
# create upper-triangle mask
mask = np.triu(np.ones_like(corr_filtered, dtype=bool))
sns.heatmap(corr_filtered, annot=True, fmt=".2f",
            annot_kws={"size":8},cmap='coolwarm', center=0,mask=mask)
plt.title('Correlation Heatmap: Logisticcorr_filtereds Performance Drivers')
plt.show() # Or plt.savefig('heatmap.png')

# %%
correlation_matrix_c['on_time_flag'].sort_values().plot.barh(figsize=(8,10))
# Out:
# <Axes: >

# %%
from sklearn.decomposition import PCA

# %%
X_train_scaled, X_test_scaled, y_train, y_test, imputer, scaler = prepare_training_data(
    df_encoded, target
)

# %%
# 2. Apply PCA
# We start by not limiting components to see how much variance they explain
pca = PCA()
X_pca = pca.fit_transform(X_train_scaled)

# 3. Determine how many components to keep (The "Scree Plot")
exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(exp_var_cumul) + 1), exp_var_cumul, marker='o', linestyle='--')
plt.axhline(y=0.95, color='r', linestyle='-')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# 4. Re-run PCA with the chosen number of components (e.g., to keep 95% variance)
pca_final = PCA(n_components=0.95)
X_train_pca = pca_final.fit_transform(X_train_scaled)
X_test_pca = pca_final.transform(X_test_scaled)

print(f"Original feature count: {X_train_scaled.shape[1]}")
print(f"Reduced feature count: {X_train_pca.shape[1]}")
# Out:
# Original feature count: 44
# Reduced feature count: 36

# %%
def apply_pca(X_train_scaled, X_test_scaled, n_components=0.95):
    pca = PCA(n_components=n_components)

    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca = pca.transform(X_test_scaled)

    return X_train_pca, X_test_pca, pca

# %%
# Calculate the Cumulative Sum of the Explained Variance
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# Set the optimal k value (based on our analysis, we can choose 6)
optimal_k = 36
# Set seaborn plot style
sns.set(rc={'axes.facecolor': '#fcf0dc'}, style='darkgrid')
# Plot the cumulative explained variance against the number of components
plt.figure(figsize=(20, 10))

# Bar chart for the explained variance of each component
barplot = sns.barplot(x=list(range(1, len(cumulative_explained_variance) + 1)),
                      y=explained_variance_ratio,
                      color='#fcc36d',
                      alpha=0.8)

# Line plot for the cumulative explained variance
lineplot, = plt.plot(range(0, len(cumulative_explained_variance)), cumulative_explained_variance,
                     marker='o', linestyle='--', color='#ff6200', linewidth=2)
# Plot optimal k value line
optimal_k_line = plt.axvline(optimal_k - 1, color='red', linestyle='--', label=f'Optimal k value = {optimal_k}')
# Set labels and title
plt.xlabel('Number of Components', fontsize=14)
plt.ylabel('Explained Variance', fontsize=14)
plt.title('Cumulative Variance vs. Number of Components', fontsize=18)

# Customize ticks and legend
plt.xticks(range(0, len(cumulative_explained_variance)))
plt.legend(handles=[barplot.patches[0], lineplot, optimal_k_line],
           labels=['Explained Variance of Each Component', 'Cumulative Explained Variance', f'Optimal k value = {optimal_k}'],
           loc=(0.62, 0.1),
           frameon=True,
           framealpha=1.0,  
           edgecolor='#ff6200')
# Display the variance values for both graphs on the plots
x_offset = -0.3
y_offset = 0.01
for i, (ev_ratio, cum_ev_ratio) in enumerate(zip(explained_variance_ratio, cumulative_explained_variance)):
    plt.text(i, ev_ratio, f"{ev_ratio:.2f}", ha="center", va="bottom", fontsize=10)
    if i > 0:
        plt.text(i + x_offset, cum_ev_ratio + y_offset, f"{cum_ev_ratio:.2f}", ha="center", va="bottom", fontsize=10)

plt.grid(axis='both')   
plt.show()

# %%
# PCA scores as DataFrames
pc_columns = [f'PC{i+1}' for i in range(pca_final.n_components_)]

X_train_pca_df = pd.DataFrame(X_train_pca, columns=pc_columns, index=X_train_scaled.index)
X_test_pca_df = pd.DataFrame(X_test_pca, columns=pc_columns, index=X_test_scaled.index)

# %%
# Define a function to highlight the top 3 absolute values in each column
def highlight_top3(column):
    top3 = column.abs().nlargest(3).index
    return ['background-color: #ffeacc' if i in top3 else '' for i in column.index]

# Create feature names since we lost them during scaling
feature_names = [f'Feature_{i+1}' for i in range(X_train_scaled.shape[1])]

# Create the PCA loadings dataframe
pc_df = pd.DataFrame(
    pca_final.components_.T,
    columns=[f'PC{i+1}' for i in range(pca_final.n_components_)],
    index=feature_names
)

pc_df.style.apply(highlight_top3, axis=0)
# Out:
# <style type="text/css">
# #T_74a26_row0_col1, #T_74a26_row1_col4, #T_74a26_row1_col33, #T_74a26_row1_col34, #T_74a26_row2_col11, #T_74a26_row2_col34, #T_74a26_row3_col5, #T_74a26_row4_col26, #T_74a26_row4_col27, #T_74a26_row4_col30, #T_74a26_row4_col31, #T_74a26_row5_col0, #T_74a26_row6_col27, #T_74a26_row6_col28, #T_74a26_row6_col30, #T_74a26_row6_col31, #T_74a26_row7_col2, #T_74a26_row8_col2, #T_74a26_row8_col26, #T_74a26_row8_col29, #T_74a26_row8_col31, #T_74a26_row9_col28, #T_74a26_row9_col29, #T_74a26_row10_col0, #T_74a26_row10_col5, #T_74a26_row10_col35, #T_74a26_row11_col13, #T_74a26_row11_col32, #T_74a26_row11_col33, #T_74a26_row12_col1, #T_74a26_row12_col4, #T_74a26_row13_col2, #T_74a26_row14_col0, #T_74a26_row14_col5, #T_74a26_row15_col26, #T_74a26_row15_col30, #T_74a26_row16_col6, #T_74a26_row17_col3, #T_74a26_row17_col6, #T_74a26_row17_col8, #T_74a26_row17_col9, #T_74a26_row18_col6, #T_74a26_row18_col9, #T_74a26_row18_col10, #T_74a26_row19_col7, #T_74a26_row19_col8, #T_74a26_row20_col7, #T_74a26_row20_col10, #T_74a26_row21_col7, #T_74a26_row21_col8, #T_74a26_row21_col9, #T_74a26_row21_col10, #T_74a26_row22_col1, #T_74a26_row22_col4, #T_74a26_row23_col3, #T_74a26_row24_col3, #T_74a26_row25_col27, #T_74a26_row25_col28, #T_74a26_row25_col29, #T_74a26_row26_col16, #T_74a26_row26_col19, #T_74a26_row27_col21, #T_74a26_row27_col22, #T_74a26_row27_col24, #T_74a26_row28_col17, #T_74a26_row28_col20, #T_74a26_row28_col25, #T_74a26_row28_col32, #T_74a26_row29_col23, #T_74a26_row29_col24, #T_74a26_row29_col25, #T_74a26_row30_col20, #T_74a26_row31_col22, #T_74a26_row31_col23, #T_74a26_row31_col33, #T_74a26_row32_col25, #T_74a26_row32_col32, #T_74a26_row33_col14, #T_74a26_row33_col19, #T_74a26_row33_col20, #T_74a26_row33_col21, #T_74a26_row34_col12, #T_74a26_row34_col13, #T_74a26_row34_col14, #T_74a26_row35_col15, #T_74a26_row35_col17, #T_74a26_row35_col18, #T_74a26_row36_col21, #T_74a26_row36_col22, #T_74a26_row37_col11, #T_74a26_row37_col18, #T_74a26_row37_col19, #T_74a26_row37_col34, #T_74a26_row38_col14, #T_74a26_row38_col16, #T_74a26_row38_col18, #T_74a26_row39_col15, #T_74a26_row39_col35, #T_74a26_row40_col12, #T_74a26_row40_col13, #T_74a26_row40_col16, #T_74a26_row40_col17, #T_74a26_row41_col23, #T_74a26_row41_col24, #T_74a26_row42_col11, #T_74a26_row42_col12, #T_74a26_row43_col15, #T_74a26_row43_col35 {
#   background-color: #ffeacc;
# }
# </style>
# <table id="T_74a26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74a26_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_74a26_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_74a26_level0_col2" class="col_heading level0 col2" >PC3</th>
#       <th id="T_74a26_level0_col3" class="col_heading level0 col3" >PC4</th>
#       <th id="T_74a26_level0_col4" class="col_heading level0 col4" >PC5</th>
#       <th id="T_74a26_level0_col5" class="col_heading level0 col5" >PC6</th>
#       <th id="T_74a26_level0_col6" class="col_heading level0 col6" >PC7</th>
#       <th id="T_74a26_level0_col7" class="col_heading level0 col7" >PC8</th>
#       <th id="T_74a26_level0_col8" class="col_heading level0 col8" >PC9</th>
#       <th id="T_74a26_level0_col9" class="col_heading level0 col9" >PC10</th>
#       <th id="T_74a26_level0_col10" class="col_heading level0 col10" >PC11</th>
#       <th id="T_74a26_level0_col11" class="col_heading level0 col11" >PC12</th>
#       <th id="T_74a26_level0_col12" class="col_heading level0 col12" >PC13</th>
#       <th id="T_74a26_level0_col13" class="col_heading level0 col13" >PC14</th>
#       <th id="T_74a26_level0_col14" class="col_heading level0 col14" >PC15</th>
#       <th id="T_74a26_level0_col15" class="col_heading level0 col15" >PC16</th>
#       <th id="T_74a26_level0_col16" class="col_heading level0 col16" >PC17</th>
#       <th id="T_74a26_level0_col17" class="col_heading level0 col17" >PC18</th>
#       <th id="T_74a26_level0_col18" class="col_heading level0 col18" >PC19</th>
#       <th id="T_74a26_level0_col19" class="col_heading level0 col19" >PC20</th>
#       <th id="T_74a26_level0_col20" class="col_heading level0 col20" >PC21</th>
#       <th id="T_74a26_level0_col21" class="col_heading level0 col21" >PC22</th>
#       <th id="T_74a26_level0_col22" class="col_heading level0 col22" >PC23</th>
#       <th id="T_74a26_level0_col23" class="col_heading level0 col23" >PC24</th>
#       <th id="T_74a26_level0_col24" class="col_heading level0 col24" >PC25</th>
#       <th id="T_74a26_level0_col25" class="col_heading level0 col25" >PC26</th>
#       <th id="T_74a26_level0_col26" class="col_heading level0 col26" >PC27</th>
#       <th id="T_74a26_level0_col27" class="col_heading level0 col27" >PC28</th>
#       <th id="T_74a26_level0_col28" class="col_heading level0 col28" >PC29</th>
#       <th id="T_74a26_level0_col29" class="col_heading level0 col29" >PC30</th>
#       <th id="T_74a26_level0_col30" class="col_heading level0 col30" >PC31</th>
#       <th id="T_74a26_level0_col31" class="col_heading level0 col31" >PC32</th>
#       <th id="T_74a26_level0_col32" class="col_heading level0 col32" >PC33</th>
#       <th id="T_74a26_level0_col33" class="col_heading level0 col33" >PC34</th>
#       <th id="T_74a26_level0_col34" class="col_heading level0 col34" >PC35</th>
#       <th id="T_74a26_level0_col35" class="col_heading level0 col35" >PC36</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74a26_level0_row0" class="row_heading level0 row0" >Feature_1</th>
#       <td id="T_74a26_row0_col0" class="data row0 col0" >0.279021</td>
#       <td id="T_74a26_row0_col1" class="data row0 col1" >0.527557</td>
#       <td id="T_74a26_row0_col2" class="data row0 col2" >-0.003444</td>
#       <td id="T_74a26_row0_col3" class="data row0 col3" >0.001445</td>
#       <td id="T_74a26_row0_col4" class="data row0 col4" >0.264093</td>
#       <td id="T_74a26_row0_col5" class="data row0 col5" >0.003100</td>
#       <td id="T_74a26_row0_col6" class="data row0 col6" >-0.037771</td>
#       <td id="T_74a26_row0_col7" class="data row0 col7" >-0.006193</td>
#       <td id="T_74a26_row0_col8" class="data row0 col8" >0.009293</td>
#       <td id="T_74a26_row0_col9" class="data row0 col9" >0.002885</td>
#       <td id="T_74a26_row0_col10" class="data row0 col10" >0.030422</td>
#       <td id="T_74a26_row0_col11" class="data row0 col11" >0.044644</td>
#       <td id="T_74a26_row0_col12" class="data row0 col12" >-0.032971</td>
#       <td id="T_74a26_row0_col13" class="data row0 col13" >-0.005364</td>
#       <td id="T_74a26_row0_col14" class="data row0 col14" >0.001315</td>
#       <td id="T_74a26_row0_col15" class="data row0 col15" >0.010848</td>
#       <td id="T_74a26_row0_col16" class="data row0 col16" >-0.000662</td>
#       <td id="T_74a26_row0_col17" class="data row0 col17" >0.012851</td>
#       <td id="T_74a26_row0_col18" class="data row0 col18" >0.014671</td>
#       <td id="T_74a26_row0_col19" class="data row0 col19" >-0.010473</td>
#       <td id="T_74a26_row0_col20" class="data row0 col20" >0.002897</td>
#       <td id="T_74a26_row0_col21" class="data row0 col21" >-0.004102</td>
#       <td id="T_74a26_row0_col22" class="data row0 col22" >-0.009812</td>
#       <td id="T_74a26_row0_col23" class="data row0 col23" >0.008273</td>
#       <td id="T_74a26_row0_col24" class="data row0 col24" >-0.016434</td>
#       <td id="T_74a26_row0_col25" class="data row0 col25" >0.020545</td>
#       <td id="T_74a26_row0_col26" class="data row0 col26" >-0.000926</td>
#       <td id="T_74a26_row0_col27" class="data row0 col27" >0.015767</td>
#       <td id="T_74a26_row0_col28" class="data row0 col28" >-0.005984</td>
#       <td id="T_74a26_row0_col29" class="data row0 col29" >0.012590</td>
#       <td id="T_74a26_row0_col30" class="data row0 col30" >0.000241</td>
#       <td id="T_74a26_row0_col31" class="data row0 col31" >0.020292</td>
#       <td id="T_74a26_row0_col32" class="data row0 col32" >-0.106490</td>
#       <td id="T_74a26_row0_col33" class="data row0 col33" >0.191644</td>
#       <td id="T_74a26_row0_col34" class="data row0 col34" >-0.144220</td>
